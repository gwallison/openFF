# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
yr = [x+2000 for x in range(20)]
yrtk = [2000,2004,2008,2012,2016,2020]

# %%
hwell = [8627,9129,9577,10372,11711,13854,16877,21647,28342,33567,41295,52560,66426,
        81947,98829,111888,117817,127315,140576,153006]

# %%
df = pd.DataFrame({'year':yr,'Horiz_wells':hwell})
df.plot('year','Horiz_wells',xlabel='year',xticks=yrtk, title="Number of Horizontal Wells in the US")
